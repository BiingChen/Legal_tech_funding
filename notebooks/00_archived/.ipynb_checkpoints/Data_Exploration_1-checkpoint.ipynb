# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# !ls ../../data/interim/
# Out:
# datasheet_1.csv

# %%
path = '../../data/interim/datasheet_1.csv'

# %%
df = pd.read_csv(path, index_col = 0)

# %%
df.codex_category.value_counts()
# Out:
# Legal Document Automation    85
# Legal Practice Management    68
# Legal Compliance             53
# Legal Marketplace            46
# Legal Analytics              30
# Legal Research               27
# E-Discovery                  20
# Online Dispute Resolution     8
# e-Discovery                   1
# Legal Education               1
# Name: codex_category, dtype: int64

# %%
df.head(5)
# Out:
#     firm_id     firm_name             codex_category       country  \
# 0  FIRM0002    LexisNexis             Legal Research           USA
# 1  FIRM0003      Korbitec  Legal Document Automation  South Africa
# 2  FIRM0014  Microsystems  Legal Document Automation           USA
# 3  FIRM0015  WorkProducts  Legal Practice Management           USA
# 4  FIRM0021    LiveOffice  Legal Practice Management           USA
#
#          city  year_founded     market problem_1 problem_2 problem_3  \
# 0    New York          1973  Corporate        LR       OPT       NaN
# 1   Cape Town          1976  Corporate         C       OPT       NaN
# 2    Illinois          1995  Corporate         C         K        LT
# 3    Virginia          1995  Corporate         E       OPT       NaN
# 4  California          1998  Corporate         K         E       NaN
#
#    analytics  ai     point_integrated  \
# 0          1   0  Integrated Solution
# 1          1   0  Integrated Solution
# ...

# %% [markdown]
# ## Analytics

# %%
df.analytics.value_counts(normalize=True).plot(kind='bar')
plt.xticks([0,1],['Analytics','No Analytics'])
# Out:
# ([<matplotlib.axis.XTick at 0x1a16b65400>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
df.analytics.value_counts(normalize=True).head(1).plot(kind='bar')
plt.title("Percentage of companies utilizing analytics")
# Out:
# Text(0.5,1,'Percentage of companies utilizing analytics')

# %%
df.analytics.mean()
# Out:
# 0.6460176991150443

# %%
print(df.groupby('market').analytics.value_counts())
df.groupby('market').analytics.value_counts().plot(kind='bar')
# Out:
# market     analytics
# Consumer   0             46
#            1              7
# Corporate  1            212
#            0             70
# Name: analytics, dtype: int64

# %%
df.groupby('market').analytics.mean().plot('bar')

# %%
df.head(2)
# Out:
#     firm_id   firm_name             codex_category       country       city  \
# 0  FIRM0002  LexisNexis             Legal Research           USA   New York
# 1  FIRM0003    Korbitec  Legal Document Automation  South Africa  Cape Town
#
#    year_founded     market       problem_1            problem_2 problem_3  \
# 0          1973  Corporate  Legal Research  Other Practice Tech       NaN
# 1          1976  Corporate       Contracts  Other Practice Tech       NaN
#
#    analytics  ai     point_integrated  \
# 0          1   0  Integrated Solution
# 1          1   0  Integrated Solution
#
#                                      company_url  \
# 0  https://www.lexisnexis.com/en-us/gateway.page
# 1                  https://www.lexisnexis.co.za/
#
#                                           other_link  \
# 0                                                NaN
# 1  https://www.linkedin.com/company/korbitec/?ori...
#
#                                            comments
# ...

# %% [markdown]
# ### Try to find AI percentage by Codex

# %%
df.groupby('codex_category').analytics.mean().sort_values().plot(kind='bar')

# %%
df.groupby('codex_category')['analytics'].mean().sort_values().plot(kind='bar')

# %%
df.groupby('codex_category')['ai'].mean().sort_values().plot(kind='bar')

# %%
df.groupby(['codex_category','market'])['analytics'].mean().sort_values().plot(kind='bar')

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
 
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = [12, 30, 1, 8, 22]
bars2 = [28, 6, 16, 5, 10]
bars3 = [29, 3, 24, 25, 17]
 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]
 
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='var1')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='var2')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='var3')
 
# Add xticks on the middle of the group bars
plt.xlabel('group', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E'])
 
# Create legend & Show graphic
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
sns.barplot()

# %%
smth = df.groupby(['market', 'codex_category'])['analytics'].mean()
smth = smth.reset_index()
sns.barplot(x='codex_category', y='analytics',hue='market', data = smth)
plt.legend(loc='upper right')
plt.xticks(rotation=90);

# %%
smth = df.groupby(['market', 'codex_category'])['ai'].mean()
smth = smth.reset_index()
sns.barplot(x='codex_category', y='ai',hue='market', data = smth)
plt.legend(loc='upper right')
plt.xticks(rotation=90);
